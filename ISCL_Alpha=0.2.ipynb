# %%
import csv
import math 
import networkx as nx
import numpy as np
from operator import itemgetter
from numpy import linalg as LA
import pandas as pd
G=nx.Graph()
f = open("bio-dmela.txt", "r")
edge1=[]
edge2=[]
nodelist=[]
for x in f:
  e1,e2=x.split()
  edge1.append(int(e1)-1)
  edge2.append(int(e2)-1)
  for i in (int(e1)-1,int(e2)-1):
      if i not in nodelist:
          nodelist.append(i)
n=len(nodelist)

for  i in range(0, len(edge1)):
    G.add_edge(edge1[i], edge2[i])
D={node:val for (node, val) in G.degree()}
CC=nx.clustering(G)
d=[val for (node,val) in G.degree()]
S_del=min(d)



def isc(node):
    ISC_value=0
    x=list(G.neighbors(node))
#     print(f"Neighbors of node {node} are:",x)
#     print(f"length of {x} is:{len(x)}")
    N=0;
    for i in range(0,len(x)):
        if G.degree(x[i])==S_del:
#             print(x[i])
            N=N+1
#     print(f'The Number of Neighbors for node {node} with deg delta is:', {N})
    ISC_value=N*G.degree(node)
    return ISC_value




#beta=[0,0.2,0.4,0.6,0.8,1]
beta=0.2
def MCisc(v, alpha):
    sum=0
    for u in nodelist:
        if v!=u:
            d_ij=nx.shortest_path_length(G, source=u, target=v)
            sum=sum+(CC[u]+isc(u)/n)/d_ij
    return sum*(beta*CC[v]+(1-beta)*isc(v)/n)
                     



mc={}
alpha=0.0
for v in nodelist:
    #print(MCisc(v,alpha))
    mc[v]=MCisc(v,alpha)


def get_key(dictionay, val):
    for key, value in dictionay.items():
         if val == value:
             return key

def get_vertices(List):
    if type(List)==list:
        res = sorted(range(len(List)), key = lambda sub: List[sub])
        return res
    if type(List)==dict:
        res = dict(sorted(List.items(), key = itemgetter(1), reverse = True)) 
        return res





#for clustering coefficent centrality values and vertices
# vertices_clustcd=get_vertices(CC)
# vertices_clustc=[]
# values_clustc=[]
# for i in vertices_clustcd:
#     vertices_clustc.append(i)
#     values_clustc.append(vertices_clustcd[i])
# #vertices_cc.reverse()
# #values_cc.reverse()
# print("vertices of clustc ", vertices_clustc)
# print("value of clustc: ", values_clustc)





#for mc centrality values and vertices

vertices_mc=get_vertices(mc)
vertices_m=[]
values_m=[]
for i in vertices_mc:
    vertices_m.append(i)
    values_m.append(vertices_mc[i])
#vertices_cc.reverse()
#values_cc.reverse()
print(f"vertices of mc when beta= {beta} :", vertices_m)
print("value of mc: ", values_m)

print("Top-10 Vertices: ",vertices_m[:10])
print("Top-10 Values: ",values_m[:10])


# n=10
# x=[]
# MC_=[]
# #print(len(G.nodes))
# for i in range(0,round(len(G.nodes())*0.75),n):
#     new_G=nx.Graph()
#     new_G = G.copy()
#     new_G.remove_nodes_from(vertices_m[:i])
#     #print(G.nodes)
#     #print("Gnodes",len(G.nodes))
#     #print("newGnodes",len(new_G.nodes))
#     x.append(i)
#     MC_.append(nx.number_connected_components(new_G))
#     #print(i)
# #print(x)
# #print(ISC_D)
# #print(len(nodes[:i]))

# df=pd.DataFrame(list(zip(x,MC_)),columns=['No_of_Nodes_Removed','No_of_Connected_Components'])
# print(df)
# df.to_excel('Bio_MC_No_Connected_Components.xlsx','Sheet1')

# df1=pd.DataFrame(list(zip(values_m,vertices_m)),columns=['Values','Vertices'])
# print(df1)
# df1.to_excel('Bio_MC_VN.xlsx','Sheet1')
# Out:
# vertices of mc when beta= 0.2 : [662, 214, 4420, 4653, 6006, 785, 5691, 1234, 4729, 4379, 1596, 6084, 4715, 3948, 6960, 883, 5400, 5185, 5653, 6791, 5225, 1133, 4936, 5405, 6047, 2069, 707, 1707, 1317, 2767, 6348, 4807, 3648, 267, 6121, 1173, 203, 603, 1671, 658, 4647, 2629, 5550, 3975, 1566, 458, 505, 411, 3166, 5923, 6731, 4084, 558, 4623, 416, 4581, 5963, 845, 3221, 4815, 4281, 298, 1832, 2039, 3241, 2924, 2489, 5724, 5022, 4258, 2877, 954, 2189, 4667, 3310, 2588, 3969, 455, 6409, 4413, 6600, 174, 383, 1416, 3442, 190, 2194, 1367, 138, 905, 6194, 1377, 25, 951, 2633, 6431, 5048, 2566, 956, 1679, 1752, 271, 450, 489, 1845, 3133, 197, 1356, 2299, 1833, 1637, 1066, 1812, 4683, 1233, 743, 253, 1100, 6120, 65, 4225, 2116, 2525, 4856, 2214, 1984, 100, 886, 4386, 3635, 2338, 208, 1293, 1855, 4337, 6706, 319, 4732, 1652, 1708, 2584, 3419, 3844, 3173, 5314, 5748, 6871, 4002, 768, 5643, 3932, 4238, 3762, 6181, 2259, 1195, 4902, 4670, 3062, 6015, 938, 5294, 840, 1363, 1863, 1410, 739, 5, 2347, 285, 149, 376, 3040, 47, 4317, 189, 173, 3811, 1010, 1613, 2152, 2730, 992, 634, 2595, 1578, 12, 2586, 862, 5521, 2649, 2571, 844, 5874, 236, 435, 663, 784, 2123, 2543, 506, 2071, 1665, 5580, 1182, 2703, 80, 186, 741, 222, 1034, 717, 551, 884, 2429, 2321, 456, 4845, 5870, 2770, 1853, 3913, 4669, 361, 2560, 1301, 5738, 3805, 1685, 1207, 2025, 1221, 125, 6423, 4852, 213, 163, 850, 5168, 1250, 5871, 5993, 4016, 6315, 5246, 1603, 2261, 5515, 2106, 1159, 266, 4691, 2362, 188, 2854, 4945, 5896, 2094, 4458, 971, 6305, 207, 3777, 28, 290, 6005, 1152, 2230, 449, 2450, 2915, 2496, 228, 1065, 5585, 5597, 3194, 75, 5518, 3045, 4415, 2621, 374, 3836, 391, 1743, 4770, 665, 672, 340, 1098, 3492, 1455, 2469, 831, 175, 116, 3657, 27, 2012, 1830, 533, 944, 1456, 1670, 6538, 1516, 2109, 4166, 468, 2559, 1436, 1168, 529, 865, 166, 2182, 2249, 3729, 1718, 141, 1811, 1929, 1824, 526, 2509, 5540, 950, 2610, 1192, 6083, 3784, 1402, 4613, 873, 5801, 232, 5603, 2936, 878, 1775, 1595, 326, 807, 2248, 277, 566, 2773, 694, 1245, 1006, 1727, 226, 1053, 2277, 1754, 4521, 817, 2288, 365, 2021, 345, 1864, 642, 3252, 6553, 111, 3002, 169, 178, 4868, 1380, 2600, 2709, 1426, 5172, 1569, 153, 1646, 330, 725, 5608, 967, 5564, 2859, 4176, 5695, 4919, 1422, 5649, 438, 3851, 3481, 43, 3137, 77, 1354, 714, 1770, 946, 4448, 4640, 344, 6390, 270, 962, 412, 1073, 627, 779, 3800, 1636, 4080, 1014, 875, 1971, 826, 2061, 731, 649, 3662, 895, 2603, 2158, 587, 115, 2876, 1124, 5148, 5250, 1112, 14, 4764, 2225, 2090, 2172, 3487, 1655, 2070, 2038, 4847, 5377, 386, 414, 3678, 2449, 1741, 1771, 997, 262, 2599, 5485, 3709, 41, 4972, 311, 1180, 322, 9, 1302, 4040, 2804, 2553, 907, 1155, 1335, 1025, 1341, 762, 653, 1559, 869, 3864, 2125, 896, 1868, 3956, 1022, 220, 2697, 132, 6108, 229, 3313, 682, 2313, 2977, 2352, 162, 5534, 5615, 1956, 669, 5284, 69, 4170, 1058, 2135, 916, 3153, 1810, 586, 3229, 1593, 463, 2905, 3066, 1104, 5559, 96, 1957, 1880, 1338, 2358, 1462, 3095, 1284, 3367, 1019, 1539, 343, 1715, 5783, 20, 81, 1148, 2648, 131, 493, 1033, 991, 973, 1912, 870, 957, 394, 1411, 1337, 477, 2911, 3883, 4388, 904, 937, 1980, 234, 2153, 3554, 2312, 112, 5880, 1043, 317, 52, 1079, 275, 336, 622, 4678, 1170, 6018, 3311, 838, 1281, 1300, 4063, 1428, 349, 42, 1660, 3531, 2464, 307, 2626, 1919, 339, 2771, 255, 3927, 5838, 3898, 2965, 151, 1807, 3327, 292, 164, 4594, 4153, 623, 1528, 260, 530, 750, 3287, 88, 2252, 5670, 194, 1568, 3416, 1196, 1962, 1639, 1120, 2850, 4567, 1502, 2942, 837, 592, 1561, 2431, 759, 5673, 5886, 1286, 3039, 3462, 1623, 772, 689, 5598, 460, 2149, 2704, 1726, 2220, 56, 666, 2493, 2047, 5891, 369, 1134, 1573, 2628, 659, 2053, 2205, 441, 156, 2843, 246, 2145, 5570, 2239, 4338, 443, 78, 4728, 1478, 1139, 980, 185, 811, 1517, 4648, 747, 742, 2199, 413, 10, 1197, 187, 655, 1393, 2080, 4723, 965, 2034, 1321, 53, 5532, 457, 1781, 2136, 1230, 1105, 366, 1887, 541, 1370, 4911, 1891, 1736, 6094, 1413, 1064, 3903, 1213, 1674, 3043, 373, 538, 5818, 1249, 2785, 513, 3870, 1918, 2204, 631, 114,  ...
# value of mc:  [18.516278985705906, 9.503755282333595, 5.816420933330246, 5.816420933330246, 5.816420933330246, 5.349492489146019, 5.316000967584057, 5.315175743241645, 5.106974094966506, 5.066529285859915, 5.030010153155466, 4.9948629438731675, 4.979710706483069, 4.966473959034325, 4.943873366701188, 4.920531441348585, 4.786237582463848, 4.7795430292268275, 4.761290435144602, 4.697430744083402, 4.634930508220257, 4.601176648838609, 4.601176648838609, 4.520484547444386, 4.174627562773711, 3.989402475409337, 3.763251644254248, 3.73842032197061, 3.604825443930524, 3.4907003931037135, 3.309331679848598, 3.114148436077194, 3.0483813630483616, 3.0238285365122723, 2.5227328928554145, 2.36438134235613, 2.255098261945015, 2.153258646013267, 1.9959847352166777, 1.9695508292379353, 1.8911489683861666, 1.8690551295733606, 1.8553277548313465, 1.8516895470088843, 1.8405241401995212, 1.8401627811820596, 1.810889673123919, 1.7993385501636376, 1.7957448219318217, 1.7953502616525556, 1.7953502616525556, 1.7908793625437542, 1.789742142336406, 1.7845023239891162, 1.7821491387239747, 1.7801802893669296, 1.7549064214797125, 1.7368199462221279, 1.7234068052696285, 1.7167577708728363, 1.7093002016748151, 1.7005425207470624, 1.6989528722802814, 1.6982338223421936, 1.6956343911180054, 1.6760815274099987, 1.6641387535115866, 1.6626871019752782, 1.6610083156613389, 1.6557431629015125, 1.6516739278703982, 1.6457972303333661, 1.6427721789055822, 1.6418135217832661, 1.6325899791263854, 1.6229239834792926, 1.6063004300647492, 1.6056669930480496, 1.5987365033845418, 1.5849236283962664, 1.5718520321782514, 1.5416425632766204, 1.5260652232934833, 1.5257599008311493, 1.5246124806259205, 1.4659624483004638, 1.4505901173623168, 1.4487230609876494, 1.4122635057482829, 1.4080263165994753, 1.3910439339335559, 1.383561203449906, 1.3706892861970266, 1.3473770892551298, 1.3397668788185826, 1.3366263375737784, 1.335022832772342, 1.3262939840115338, 1.294619713153378, 1.2829558079105836, 1.2595569881957223, 1.2200837971665732, 1.1917593965370055, 1.1878871386050864, 1.1815067160599662, 1.1640755412006558, 1.1293655176633808, 1.1140494644667442, 1.1064880290245886, 1.098722893979437, 1.0976259018024908, 1.0954628083467697, 1.0821428973735958, 1.0790519732591601, 1.0789252021658744, 1.0730520212516104, 1.0728767736157567, 1.0683662819718434, 1.0675203377890188, 1.063622424935079, 1.0625168715132467, 1.0619541682455258, 1.0520306423331012, 1.034330121360806, 1.0248592459611439, 1.0230855537891255, 1.01900476924972, 1.01900476924972, 1.0122540733900958, 1.0075881135119045, 1.0064822190969553, 1.0019659326694377, 0.9923008838220575, 0.986717583429351, 0.9672892864565191, 0.9342397534248864, 0.9296984384228263, 0.9206639170647621, 0.9189309985830109, 0.9131826575878856, 0.9040630427735854, 0.8956786233488874, 0.8952613234671473, 0.8918148269839024, 0.8908874338580675, 0.8821157187506384, 0.8821157187506384, 0.8801410240759845, 0.8702014368155664, 0.8576320621791877, 0.8483110646046236, 0.8433681877666884, 0.8428678708363021, 0.8421023977439838, 0.8416195862632275, 0.8403592860812381, 0.8382191989509078, 0.8370150074754609, 0.8358195643921357, 0.8325476849790924, 0.8299370731039828, 0.8291506625021353, 0.8273883430323621, 0.8170567727927935, 0.8161772694425875, 0.8105583568547181, 0.8044767342688993, 0.8009220261640166, 0.7962172615740247, 0.7953783929445738, 0.7926632668825259, 0.7894051359863511, 0.7879215364642164, 0.7852325502099132, 0.7845437973741991, 0.7837533507206726, 0.772634916803097, 0.7702735320374933, 0.7578547892862553, 0.7391753386286954, 0.7358860470130058, 0.7297434727564885, 0.7222624312455722, 0.7199595644276633, 0.7162594756030906, 0.7128318466969598, 0.7107667523062344, 0.7015526248685345, 0.7011911359590921, 0.7008516029375275, 0.6994491514201143, 0.6991490174348469, 0.6972392104420768, 0.6971881597262483, 0.6863096481431223, 0.6827024314169915, 0.6783791520021258, 0.6778449943335758, 0.6690796873697638, 0.6642645610558358, 0.6620383252080534, 0.6610574892 ...
# Top-10 Vertices:  [662, 214, 4420, 4653, 6006, 785, 5691, 1234, 4729, 4379]
# Top-10 Values:  [18.516278985705906, 9.503755282333595, 5.816420933330246, 5.816420933330246, 5.816420933330246, 5.349492489146019, 5.316000967584057, 5.315175743241645, 5.106974094966506, 5.066529285859915]
