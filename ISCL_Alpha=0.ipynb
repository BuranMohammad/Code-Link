# %%
import csv
import math 
import networkx as nx
import numpy as np
from operator import itemgetter
from numpy import linalg as LA
import pandas as pd
G=nx.Graph()
f = open("bio-dmela.txt", "r")
edge1=[]
edge2=[]
nodelist=[]
for x in f:
  e1,e2=x.split()
  edge1.append(int(e1)-1)
  edge2.append(int(e2)-1)
  for i in (int(e1)-1,int(e2)-1):
      if i not in nodelist:
          nodelist.append(i)
n=len(nodelist)

for  i in range(0, len(edge1)):
    G.add_edge(edge1[i], edge2[i])
D={node:val for (node, val) in G.degree()}
CC=nx.clustering(G)
d=[val for (node,val) in G.degree()]
S_del=min(d)



def isc(node):
    ISC_value=0
    x=list(G.neighbors(node))
#     print(f"Neighbors of node {node} are:",x)
#     print(f"length of {x} is:{len(x)}")
    N=0;
    for i in range(0,len(x)):
        if G.degree(x[i])==S_del:
#             print(x[i])
            N=N+1
#     print(f'The Number of Neighbors for node {node} with deg delta is:', {N})
    ISC_value=N*G.degree(node)
    return ISC_value




#beta=[0,0.2,0.4,0.6,0.8,1]
beta=0.0
def MCisc(v, alpha):
    sum=0
    for u in nodelist:
        if v!=u:
            d_ij=nx.shortest_path_length(G, source=u, target=v)
            sum=sum+(CC[u]+isc(u)/n)/d_ij
    return sum*(beta*CC[v]+(1-beta)*isc(v)/n)
                     



mc={}
alpha=0.0
for v in nodelist:
    #print(MCisc(v,alpha))
    mc[v]=MCisc(v,alpha)


def get_key(dictionay, val):
    for key, value in dictionay.items():
         if val == value:
             return key

def get_vertices(List):
    if type(List)==list:
        res = sorted(range(len(List)), key = lambda sub: List[sub])
        return res
    if type(List)==dict:
        res = dict(sorted(List.items(), key = itemgetter(1), reverse = True)) 
        return res





#for clustering coefficent centrality values and vertices
# vertices_clustcd=get_vertices(CC)
# vertices_clustc=[]
# values_clustc=[]
# for i in vertices_clustcd:
#     vertices_clustc.append(i)
#     values_clustc.append(vertices_clustcd[i])
# #vertices_cc.reverse()
# #values_cc.reverse()
# print("vertices of clustc ", vertices_clustc)
# print("value of clustc: ", values_clustc)





#for mc centrality values and vertices

vertices_mc=get_vertices(mc)
vertices_m=[]
values_m=[]
for i in vertices_mc:
    vertices_m.append(i)
    values_m.append(vertices_mc[i])
#vertices_cc.reverse()
#values_cc.reverse()
print(f"vertices of mc when beta= {beta} :", vertices_m)
print("value of mc: ", values_m)

print("Top-10 Vertices: ",vertices_m[:10])
print("Top-10 Values: ",values_m[:10])


# n=10
# x=[]
# MC_=[]
# #print(len(G.nodes))
# for i in range(0,round(len(G.nodes())*0.75),n):
#     new_G=nx.Graph()
#     new_G = G.copy()
#     new_G.remove_nodes_from(vertices_m[:i])
#     #print(G.nodes)
#     #print("Gnodes",len(G.nodes))
#     #print("newGnodes",len(new_G.nodes))
#     x.append(i)
#     MC_.append(nx.number_connected_components(new_G))
#     #print(i)
# #print(x)
# #print(ISC_D)
# #print(len(nodes[:i]))

# df=pd.DataFrame(list(zip(x,MC_)),columns=['No_of_Nodes_Removed','No_of_Connected_Components'])
# print(df)
# df.to_excel('Bio_MC_No_Connected_Components.xlsx','Sheet1')

# df1=pd.DataFrame(list(zip(values_m,vertices_m)),columns=['Values','Vertices'])
# print(df1)
# df1.to_excel('Bio_MC_VN.xlsx','Sheet1')
# Out:
# vertices of mc when beta= 0.0 : [662, 214, 707, 267, 203, 603, 5550, 298, 455, 383, 174, 2194, 951, 25, 138, 956, 1679, 905, 1752, 450, 489, 197, 1066, 1637, 1100, 2116, 65, 1377, 253, 1293, 3133, 743, 208, 768, 739, 840, 1410, 285, 1613, 634, 992, 5, 1363, 236, 741, 222, 186, 12, 456, 2560, 717, 844, 2025, 663, 1250, 319, 1221, 2321, 2915, 163, 1685, 188, 551, 1830, 1456, 266, 2770, 1207, 75, 5585, 831, 1065, 533, 1718, 340, 213, 125, 207, 865, 672, 950, 28, 4166, 232, 1245, 468, 141, 1168, 277, 1516, 2469, 2586, 3252, 1006, 506, 330, 587, 2288, 169, 1670, 1053, 1073, 2182, 5608, 262, 878, 2248, 807, 414, 2610, 1655, 2038, 149, 762, 779, 1741, 311, 1302, 682, 944, 2553, 1354, 2648, 957, 438, 220, 937, 1593, 1180, 2876, 153, 2911, 3883, 1636, 307, 916, 151, 234, 2021, 896, 2172, 1104, 973, 870, 2239, 52, 1478, 2936, 907, 2199, 187, 2080, 1335, 2034, 156, 460, 4153, 3554, 4911, 365, 967, 2464, 9, 114, 2205, 3313, 366, 4181, 443, 273, 1386, 2149, 1980, 2220, 1781, 317, 750, 101, 304, 81, 1134, 461, 111, 457, 1137, 3039, 530, 463, 649, 391, 513, 5695, 23, 1196, 246, 3850, 359, 3870, 436, 2218, 1445, 1341, 586, 1891, 1550, 2697, 2668, 2579, 2430, 3740, 56, 1411, 1810, 2449, 2442, 5891, 1249, 1200, 659, 3002, 329, 631, 1393, 3066, 5576, 805, 1680, 231, 2276, 2260, 1715, 2320, 1517, 1, 548, 1624, 128, 1290, 1083, 225, 2269, 1634, 1383, 2335, 797, 1079, 837, 3820, 1111, 485, 2053, 2976, 720, 848, 4567, 339, 817, 4400, 2169, 3167, 5625, 514, 1807, 538, 5666, 1997, 1962, 5570, 3524, 3864, 1674, 289, 2630, 966, 766, 53, 157, 118, 503, 1831, 5606, 2327, 801, 2302, 557, 2181, 991, 638, 1120, 2102, 1149, 4728, 1539, 681, 2325, 4473, 4842, 1081, 293, 1667, 510, 5679, 1235, 394, 693, 328, 1408, 1471, 2118, 1038, 78, 921, 388, 1890, 1426, 851, 546, 6328, 2211, 5590, 1227, 3645, 772, 4575, 4289, 3898, 605, 2099, 1531, 1058, 1279, 1069, 1462, 5532, 2277, 5591, 405, 3195, 3847, 1192, 77, 385, 2460, 5546, 1638, 1887, 3290, 1939, 1834, 1483, 3597, 4290, 1508, 1692, 2178, 2204, 4508, 1205, 705, 5318, 500, 3995, 1616, 3578, 2263, 498, 889, 582, 4797, 719, 780, 709, 4530, 753, 477, 3370, 2004, 847, 2989, 322, 764, 4588, 341, 524, 1263, 331, 1385, 120, 3153, 142, 1276, 864, 2431, 1315, 665, 2467, 2389, 2472, 2115, 136, 1608, 5714, 5261, 3594, 1629, 5619, 3208, 4065, 279, 862, 318, 2759, 5335, 6083, 5802, 6325, 5702, 941, 2213, 4981, 2156, 2411, 290, 1060, 616, 2040, 1005, 2534, 1740, 639, 1764, 36, 32, 1169, 2673, 107, 1391, 1957, 517, 655, 168, 1586, 2606, 1906, 686, 390, 2589, 95, 3330, 1510, 1989, 2197, 1649, 1123, 4969, 806, 64, 2509, 2427, 869, 2058, 1611, 715, 160, 1974, 1272, 1161, 67, 841, 1606, 2480, 1139, 3565, 4532, 1306, 427, 1420, 475, 2406, 89, 2089, 2625, 412, 1375, 1419, 3028, 519, 1639, 5828, 230, 2246, 4813, 5926, 1407, 5542, 2151, 891, 354, 5821, 1765, 1766, 680, 3732, 4723, 2221, 2535, 516, 860, 5928, 5431, 1310, 58, 3596, 3724, 2607, 1561, 716, 1070, 3199, 313, 1448, 170, 2416, 685, 1499, 462, 254, 1792, 751, 2930, 856, 985, 1978, 5756, 5648, 5849, 547, 803, 287, 1806, 4293, 5592, 2659, 1704, 3454, 2487, 2134, 5292, 2440, 1564, 2768, 4183, 1899, 769, 4481, 691, 770, 6461, 57, 4085, 1487, 4867, 87, 781, 452, 2525, 3674, 4089, 2313, 669, 1321, 2300, 3529, 180, 1241, 970, 2358, 694, 1343, 2254, 1431, 1498, 1019, 2272, 5915, 736, 572, 3080, 3605, 997, 2415, 706, 3466, 370, 635, 3842, 3458, 109, 2217, 2660, 820, 1034, 1748, 372, 3329, 1107, 2711, 3356, 444, 3631, 1166, 866, 129, 1268, 2521, 1555, 1854, 31, 1895, 2298, 1993, 1880, 565, 4059, 2568, 255, 579, 6466, 2365, 2728, 1097, 2851, 1769, 998, 1148, 5959, 933, 1049, 2057, 1128, 4039, 1430, 2588, 648, 14, 1813, 5890, 2950, 5940, 2035, 3129, 1695, 5547, 2323, 6167, 1658, 2573, 1497, 1946, 5199, 252, 1664, 5851, 1307, 93, 6026, 1000, 1728, 1232, 3508, 2238, 566, 159, 775, 6493, 2875, 6166, 1848, 996, 4825, 1590, 2401, 3444, 1934, 6414, 4264, 3075, 1948, 2074, 1858, 1274, 1382, 3540, 4502, 1751, 1361, 799, 4415, 1935, 1288, 815, 2922, 4269, 418, 3127, 2448, 3072, 5566, 5616, 3210, 2667, ...
# value of mc:  [23.126045768994484, 11.828427010689333, 4.670512566517665, 3.7757343993804406, 2.7569692628236484, 2.6235542477109255, 2.290539323874412, 2.0819155411945065, 1.948818607008683, 1.8801732265167588, 1.8210253568524883, 1.813237646702896, 1.684221361568912, 1.680972198989355, 1.6584147532953752, 1.6182746414417224, 1.5942506134258438, 1.5852028045121567, 1.5744462352446524, 1.4407929896009188, 1.4013325724770804, 1.3962077798089498, 1.3588822437773536, 1.3409495674943568, 1.335457852464804, 1.327442710306907, 1.311503152366342, 1.2336904868897862, 1.223970086902649, 1.194305761661383, 1.19267125437093, 1.1684645210654265, 1.140595600743183, 1.0877517960194578, 0.9949900699019608, 0.9774625187905326, 0.9460802423312541, 0.9285721224354511, 0.9025820292404381, 0.8821022150424906, 0.8739993196769603, 0.8637383709209304, 0.8476994547681216, 0.8085423918874559, 0.7919888612852682, 0.7760872704784947, 0.762387555346361, 0.7507297684815293, 0.7252072819103162, 0.714303639154546, 0.7037922755524063, 0.703326441908657, 0.7027464608202783, 0.669125990170815, 0.6633958777102668, 0.6604938824711898, 0.6460838282934083, 0.6432537721325601, 0.6408555818721982, 0.6292582108729114, 0.6068825348836999, 0.6066481095178666, 0.6065225333754074, 0.5879871327902304, 0.5851257209038421, 0.5828189101374083, 0.5685279466655606, 0.568329209131629, 0.5671996355224301, 0.5573727168052796, 0.5501405522532455, 0.5475042950810408, 0.547295743245297, 0.5458470544583994, 0.5456527675179822, 0.5406936356450629, 0.5400580349455242, 0.5373157824825382, 0.5329747536569193, 0.5311585102838515, 0.5301480032317099, 0.5294916585033868, 0.5259867418934445, 0.5157986107666304, 0.5020044416937505, 0.5012183126745396, 0.49707224511458575, 0.4913924422754903, 0.48088898109016454, 0.4709474204263577, 0.46750627992683447, 0.4646006936617449, 0.46144160524329947, 0.45762662921027064, 0.457461955029319, 0.44638510619488275, 0.4406561356280182, 0.4367581029823508, 0.4343176526532561, 0.43335688921660276, 0.4315540563976013, 0.43049940025138905, 0.4283279632178114, 0.4251958369056278, 0.42229620632927706, 0.42168322222185023, 0.4178342766894624, 0.41734896521174264, 0.4095384198481237, 0.4048670465768911, 0.40225799867635414, 0.4001976290473964, 0.39208527398966625, 0.38808375352256086, 0.3798326448766343, 0.37413261067386505, 0.37356375237445955, 0.369276073173164, 0.3680478258539159, 0.3649836428704378, 0.3587790879619901, 0.3581239866439788, 0.35811506373919166, 0.3536216659298384, 0.3535964330758173, 0.3492955350819894, 0.3463607768935603, 0.3445974751557303, 0.34459381182819615, 0.3445627993037202, 0.34398266014263257, 0.33167569098605676, 0.33009341956150356, 0.3297660190685631, 0.32871180331124406, 0.32628807686666134, 0.3262601914365666, 0.3227859216752356, 0.31645018478757675, 0.31464410416624244, 0.31058357850867613, 0.3072035810794499, 0.2998527154124157, 0.2988359738422176, 0.29651866187167725, 0.2960432129812306, 0.29566371536001296, 0.29531505754680626, 0.2938891753678, 0.2926786673723618, 0.29235030286672103, 0.29026455253001415, 0.28937724597702363, 0.28771318852888905, 0.2866380402604292, 0.2839557131769298, 0.28352114486937624, 0.2829590640066463, 0.2809700681486539, 0.27941064194304055, 0.27735281402985573, 0.27620115723815736, 0.27347523322391804, 0.26861897977588783, 0.26793111936737013, 0.267500574583198, 0.2666234147192179, 0.26551616826735114, 0.2650545214888696, 0.2607941491763295, 0.26035015181280147, 0.25642984207232006, 0.2551724826839075, 0.25492757571684393, 0.25406088079450306, 0.25160322833447984, 0.2513625799507914, 0.2503101425612776, 0.24977311832110782, 0.24868109366077218, 0.24770659894729935, 0.24697993715811628, 0.24676444768379535, 0.24601675585136035, 0.24530902081346814, 0.2451948123964458, 0.24385163868005413, 0.24237500998635128, 0.2417793255166934, 0.24160181515434798, 0.23951602197611546, 0.23780490813287747, 0.23681907289241153, 0.2349719325195381, 0.23356853290809626, 0.23202763278480135, 0.23196937342487814, 0.2283646 ...
# Top-10 Vertices:  [662, 214, 707, 267, 203, 603, 5550, 298, 455, 383]
# Top-10 Values:  [23.126045768994484, 11.828427010689333, 4.670512566517665, 3.7757343993804406, 2.7569692628236484, 2.6235542477109255, 2.290539323874412, 2.0819155411945065, 1.948818607008683, 1.8801732265167588]
