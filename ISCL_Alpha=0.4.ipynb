# %%
import csv
import math 
import networkx as nx
import numpy as np
from operator import itemgetter
from numpy import linalg as LA
import pandas as pd
G=nx.Graph()
f = open("bio-dmela.txt", "r")
edge1=[]
edge2=[]
nodelist=[]
for x in f:
  e1,e2=x.split()
  edge1.append(int(e1)-1)
  edge2.append(int(e2)-1)
  for i in (int(e1)-1,int(e2)-1):
      if i not in nodelist:
          nodelist.append(i)
n=len(nodelist)

for  i in range(0, len(edge1)):
    G.add_edge(edge1[i], edge2[i])
D={node:val for (node, val) in G.degree()}
CC=nx.clustering(G)
d=[val for (node,val) in G.degree()]
S_del=min(d)



def isc(node):
    ISC_value=0
    x=list(G.neighbors(node))
#     print(f"Neighbors of node {node} are:",x)
#     print(f"length of {x} is:{len(x)}")
    N=0;
    for i in range(0,len(x)):
        if G.degree(x[i])==S_del:
#             print(x[i])
            N=N+1
#     print(f'The Number of Neighbors for node {node} with deg delta is:', {N})
    ISC_value=N*G.degree(node)
    return ISC_value




#beta=[0,0.2,0.4,0.6,0.8,1]
beta=0.4
def MCisc(v, alpha):
    sum=0
    for u in nodelist:
        if v!=u:
            d_ij=nx.shortest_path_length(G, source=u, target=v)
            sum=sum+(CC[u]+isc(u)/n)/d_ij
    return sum*(beta*CC[v]+(1-beta)*isc(v)/n)
                     



mc={}
alpha=0.0
for v in nodelist:
    #print(MCisc(v,alpha))
    mc[v]=MCisc(v,alpha)


def get_key(dictionay, val):
    for key, value in dictionay.items():
         if val == value:
             return key

def get_vertices(List):
    if type(List)==list:
        res = sorted(range(len(List)), key = lambda sub: List[sub])
        return res
    if type(List)==dict:
        res = dict(sorted(List.items(), key = itemgetter(1), reverse = True)) 
        return res





#for clustering coefficent centrality values and vertices
# vertices_clustcd=get_vertices(CC)
# vertices_clustc=[]
# values_clustc=[]
# for i in vertices_clustcd:
#     vertices_clustc.append(i)
#     values_clustc.append(vertices_clustcd[i])
# #vertices_cc.reverse()
# #values_cc.reverse()
# print("vertices of clustc ", vertices_clustc)
# print("value of clustc: ", values_clustc)





#for mc centrality values and vertices

vertices_mc=get_vertices(mc)
vertices_m=[]
values_m=[]
for i in vertices_mc:
    vertices_m.append(i)
    values_m.append(vertices_mc[i])
#vertices_cc.reverse()
#values_cc.reverse()
print(f"vertices of mc when beta= {beta} :", vertices_m)
print("value of mc: ", values_m)

print("Top-10 Vertices: ",vertices_m[:10])
print("Top-10 Values: ",values_m[:10])


# n=10
# x=[]
# MC_=[]
# #print(len(G.nodes))
# for i in range(0,round(len(G.nodes())*0.75),n):
#     new_G=nx.Graph()
#     new_G = G.copy()
#     new_G.remove_nodes_from(vertices_m[:i])
#     #print(G.nodes)
#     #print("Gnodes",len(G.nodes))
#     #print("newGnodes",len(new_G.nodes))
#     x.append(i)
#     MC_.append(nx.number_connected_components(new_G))
#     #print(i)
# #print(x)
# #print(ISC_D)
# #print(len(nodes[:i]))

# df=pd.DataFrame(list(zip(x,MC_)),columns=['No_of_Nodes_Removed','No_of_Connected_Components'])
# print(df)
# df.to_excel('Bio_MC_No_Connected_Components.xlsx','Sheet1')

# df1=pd.DataFrame(list(zip(values_m,vertices_m)),columns=['Values','Vertices'])
# print(df1)
# df1.to_excel('Bio_MC_VN.xlsx','Sheet1')
# Out:
# vertices of mc when beta= 0.4 : [662, 4420, 4653, 6006, 785, 5691, 1234, 4729, 4379, 1596, 6084, 4715, 3948, 6960, 883, 5400, 5185, 5653, 6791, 5225, 1133, 4936, 5405, 6047, 2069, 1707, 1317, 214, 2767, 6348, 4807, 3648, 6121, 1173, 1671, 658, 4647, 2629, 3975, 1566, 458, 505, 411, 5923, 6731, 4084, 3166, 558, 4623, 416, 4581, 5963, 845, 3221, 4815, 4281, 1832, 2039, 3241, 2924, 2489, 5724, 5022, 4258, 2877, 954, 2189, 4667, 3310, 3969, 2588, 6409, 4413, 6600, 1416, 3442, 190, 1367, 707, 6194, 6431, 5048, 2633, 2566, 271, 1845, 267, 1356, 2299, 1833, 1812, 4683, 1233, 6120, 4225, 4856, 2214, 2525, 1984, 100, 886, 4386, 3635, 2338, 1855, 4337, 6706, 4732, 1652, 1708, 2584, 3419, 3844, 3173, 5314, 5748, 6871, 4002, 203, 5643, 3932, 4238, 3762, 6181, 2259, 603, 1195, 4902, 4670, 3062, 6015, 938, 5294, 1863, 2347, 376, 3040, 47, 4317, 189, 173, 3811, 1377, 1010, 2152, 2730, 2595, 1578, 5550, 5521, 2649, 2571, 5874, 435, 784, 2123, 2543, 2071, 298, 1665, 862, 5580, 1182, 2703, 80, 455, 174, 905, 884, 2429, 319, 1034, 149, 4845, 5870, 383, 138, 1853, 3913, 4669, 361, 1301, 3133, 5738, 3805, 6423, 4852, 850, 5168, 5993, 2194, 4016, 6315, 5246, 1603, 5871, 2261, 5515, 2106, 1159, 25, 4691, 2362, 2854, 4945, 5896, 2094, 4458, 971, 6305, 3777, 6005, 1152, 2230, 449, 2450, 2496, 228, 5597, 3194, 5518, 3045, 951, 2621, 374, 3836, 1743, 4770, 1098, 3492, 743, 1455, 4415, 489, 1679, 956, 175, 116, 3657, 27, 2012, 1752, 450, 290, 2586, 6538, 253, 2109, 2559, 1436, 529, 166, 665, 2249, 3729, 1811, 506, 1929, 208, 197, 526, 1637, 5540, 1402, 1824, 4613, 1066, 873, 5801, 5603, 65, 1775, 1595, 326, 3784, 2773, 1727, 226, 1100, 1754, 4521, 2116, 1293, 345, 1864, 1363, 642, 6553, 2509, 566, 178, 1380, 2600, 2709, 5172, 1569, 1646, 725, 2859, 391, 6083, 694, 4919, 1422, 5649, 3851, 4868, 43, 3137, 5, 714, 1770, 5564, 946, 4448, 4640, 4176, 344, 6390, 270, 962, 1192, 3800, 3481, 4080, 1014, 875, 1971, 826, 2061, 731, 3662, 895, 2603, 2158, 115, 1124, 5148, 5250, 1112, 4764, 627, 2225, 2090, 3487, 2070, 4847, 5377, 386, 844, 3678, 663, 1771, 840, 1410, 2599, 5485, 2277, 12, 3709, 285, 14, 41, 4972, 768, 412, 4040, 2804, 1025, 653, 1559, 2125, 1426, 1868, 3956, 1022, 997, 132, 551, 6108, 817, 229, 2977, 2352, 162, 77, 2770, 5534, 5615, 1956, 739, 69, 4170, 2135, 1155, 3229, 2905, 5559, 96, 1338, 3095, 1284, 3367, 5284, 343, 5783, 20, 125, 1613, 944, 131, 992, 493, 1033, 1912, 213, 3002, 236, 2313, 634, 1207, 669, 869, 2153, 1880, 2312, 112, 5880, 2321, 322, 1043, 275, 622, 4678, 1170, 2358, 717, 1337, 6018, 3311, 1148, 838, 1281, 1019, 1300, 4388, 4063, 904, 1428, 349, 42, 2936, 1660, 111, 3531, 2626, 1919, 2771, 3927, 5838, 2965, 1685, 3327, 292, 164, 4594, 623, 1528, 260, 3287, 336, 88, 2252, 5670, 194, 5695, 1568, 3416, 365, 1957, 2850, 186, 1502, 2942, 592, 759, 5673, 28, 3153, 2469, 5886, 207, 1286, 3462, 1623, 1670, 689, 5598, 2704, 1726, 666, 2493, 2047, 369, 1573, 222, 2628, 441, 266, 1058, 2843, 255, 2145, 1221, 1065, 967, 163, 741, 2021, 4338, 649, 3864, 980, 185, 811, 4648, 747, 2449, 742, 413, 10, 1197, 1462, 5585, 965, 456, 2182, 477, 1516, 672, 2136, 1230, 75, 188, 1105, 541, 1370, 1736, 6094, 1413, 1064, 3903, 1213, 373, 1561, 2610, 2785, 340, 1639, 1539, 1250, 1918, 5794, 2560, 2343, 528, 394, 2025, 2653, 407, 991, 1078, 573, 585, 4006, 1697, 2745, 4196, 153, 3043, 831, 468, 5818, 1168, 808, 2758, 1341, 2431, 4, 1143, 381, 3378, 2962, 1321, 2124, 2697, 3249, 5793, 4824, 4034, 2925, 5703, 878, 1677, 272, 1139, 882, 934, 3898, 552, 3066, 1755, 310, 438, 4723, 807, 533, 2248, 3309, 3455, 1636, 4166, 130, 4642, 999, 6032, 2172, 1810, 942, 1715, 2915, 1959, 655, 1309, 1183, 586, 3466, 1354, 1130, 3625, 920, 943, 9, 2893, 2568, 772, 141, 1053, 3798, 771, 5232, 1848, 865, 3155, 4089, 1120, 1079, 2876, 274, 2545, 5676, 417, 463, 4515, 2288, 2908, 1353, 1807, 1271, 3732, 2246, 1830, 3313, 339, 1456, 621, 1962, 2889, 829, 1335, 1006, 2953, 1411, 907, 1191, 1361, 1349, 779, 1012, 1907, 1051, 315, 726, 170, 78, 4567, 169, 3036, 1906, 2029, 4578, 1 ...
# value of mc:  [13.906512202417327, 11.632841866660492, 11.632841866660492, 11.632841866660492, 10.698984978292039, 10.632001935168114, 10.63035148648329, 10.213948189933012, 10.13305857171983, 10.060020306310932, 9.989725887746335, 9.959421412966138, 9.93294791806865, 9.887746733402375, 9.84106288269717, 9.572475164927695, 9.559086058453655, 9.522580870289204, 9.394861488166804, 9.269861016440514, 9.202353297677218, 9.202353297677218, 9.040969094888773, 8.349255125547423, 7.978804950818674, 7.47684064394122, 7.209650887861048, 7.179083553977857, 6.981400786207427, 6.618663359697196, 6.228296872154388, 6.096762726096723, 5.045465785710829, 4.72876268471226, 3.9919694704333555, 3.9391016584758707, 3.7822979367723333, 3.7381102591467212, 3.7033790940177687, 3.6810482803990423, 3.680325562364119, 3.621779346247838, 3.5986771003272753, 3.5907005233051112, 3.5907005233051112, 3.5817587250875085, 3.5806122018139823, 3.579484284672812, 3.5690046479782325, 3.5642982774479495, 3.5603605787338592, 3.4991827731025684, 3.4736398924442558, 3.446813610539257, 3.4335155417456726, 3.4186004033496302, 3.3979057445605627, 3.396467644684387, 3.391268782236011, 3.3521630548199974, 3.328277507023173, 3.3253742039505565, 3.3220166313226778, 3.311486325803025, 3.3033478557407965, 3.2915944606667322, 3.2855443578111645, 3.2836270435665322, 3.2651799582527707, 3.2126008601294984, 3.2025232081003154, 3.1974730067690835, 3.169847256792533, 3.143704064356503, 3.0515198016622986, 3.049224961251841, 2.9319248966009277, 2.8974461219752987, 2.855990721990831, 2.7820878678671117, 2.6732526751475567, 2.670045665544684, 2.66873063806599, 2.6525879680230675, 2.4401675943331465, 2.3630134321199323, 2.2719226736441027, 2.2280989289334885, 2.2129760580491773, 2.197445787958874, 2.1642857947471916, 2.1581039465183203, 2.157850404331749, 2.1350406755780376, 2.1250337430264934, 2.068660242721612, 2.0497184919222877, 2.0476130278484357, 2.046171107578251, 2.03800953849944, 2.03800953849944, 2.0245081467801915, 2.015176227023809, 2.0129644381939107, 1.973435166858702, 1.9345785729130383, 1.8684795068497728, 1.8413278341295243, 1.8378619971660217, 1.8263653151757713, 1.8081260855471708, 1.7913572466977747, 1.7905226469342945, 1.7836296539678047, 1.781774867716135, 1.7642314375012769, 1.7642314375012769, 1.760282048151969, 1.753227261066381, 1.7152641243583755, 1.6966221292092472, 1.6867363755333769, 1.6857357416726042, 1.6842047954879675, 1.683239172526455, 1.682963044315608, 1.6807185721624762, 1.6764383979018156, 1.6740300149509217, 1.6716391287842713, 1.6650953699581847, 1.6598741462079656, 1.6583013250042706, 1.632354538885175, 1.5924345231480495, 1.5788102719727022, 1.5758430729284327, 1.5704651004198265, 1.5690875947483982, 1.5675067014413453, 1.545269833606194, 1.5405470640749865, 1.533431920010026, 1.4878509280539136, 1.4717720940260115, 1.459486945512977, 1.4325189512061811, 1.4256636933939195, 1.4201161857882811, 1.401703205875055, 1.3988983028402286, 1.3982980348696938, 1.3943763194524965, 1.365404862833983, 1.3556899886671516, 1.3381593747395275, 1.3285291221116715, 1.3221149785019495, 1.3191695002996184, 1.3143251350397922, 1.3087879684689492, 1.2867283995267755, 1.2853151303923107, 1.2799034173752024, 1.2754958320684544, 1.262515379087416, 1.2622597697007525, 1.230849828686794, 1.2265083384398021, 1.2072807358070774, 1.1989029943744627, 1.1954272326768622, 1.1932412597753856, 1.1841791803189279, 1.1841791803189279, 1.1719572200702082, 1.1661122582011902, 1.1616175586840387, 1.160701836720012, 1.1483918430078226, 1.1450338718045516, 1.1399871462652973, 1.1354798280303813, 1.1343356412759302, 1.132454797205517, 1.1092957769068212, 1.1083836404749117, 1.1030701627084518, 1.1023833367265443, 1.0935366174340144, 1.0879425880217375, 1.0821748725275633, 1.0796068217717965, 1.0762010762526786, 1.072199396041644, 1.0718777834650692, 1.0717095721052168, 1.0708573716657772, 1.0683280347549788, 1.0674650799221703, 1.0604063734046982, 1.0589827206573474, 1.05870090940255 ...
# Top-10 Vertices:  [662, 4420, 4653, 6006, 785, 5691, 1234, 4729, 4379, 1596]
# Top-10 Values:  [13.906512202417327, 11.632841866660492, 11.632841866660492, 11.632841866660492, 10.698984978292039, 10.632001935168114, 10.63035148648329, 10.213948189933012, 10.13305857171983, 10.060020306310932]
