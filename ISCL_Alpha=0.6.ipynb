# %%
import csv
import math 
import networkx as nx
import numpy as np
from operator import itemgetter
from numpy import linalg as LA
import pandas as pd
G=nx.Graph()
f = open("bio-dmela.txt", "r")
edge1=[]
edge2=[]
nodelist=[]
for x in f:
  e1,e2=x.split()
  edge1.append(int(e1)-1)
  edge2.append(int(e2)-1)
  for i in (int(e1)-1,int(e2)-1):
      if i not in nodelist:
          nodelist.append(i)
n=len(nodelist)

for  i in range(0, len(edge1)):
    G.add_edge(edge1[i], edge2[i])
D={node:val for (node, val) in G.degree()}
CC=nx.clustering(G)
d=[val for (node,val) in G.degree()]
S_del=min(d)



def isc(node):
    ISC_value=0
    x=list(G.neighbors(node))
#     print(f"Neighbors of node {node} are:",x)
#     print(f"length of {x} is:{len(x)}")
    N=0;
    for i in range(0,len(x)):
        if G.degree(x[i])==S_del:
#             print(x[i])
            N=N+1
#     print(f'The Number of Neighbors for node {node} with deg delta is:', {N})
    ISC_value=N*G.degree(node)
    return ISC_value




#beta=[0,0.2,0.4,0.6,0.8,1]
beta=0.6
def MCisc(v, alpha):
    sum=0
    for u in nodelist:
        if v!=u:
            d_ij=nx.shortest_path_length(G, source=u, target=v)
            sum=sum+(CC[u]+isc(u)/n)/d_ij
    return sum*(beta*CC[v]+(1-beta)*isc(v)/n)
                     



mc={}
alpha=0.0
for v in nodelist:
    #print(MCisc(v,alpha))
    mc[v]=MCisc(v,alpha)


def get_key(dictionay, val):
    for key, value in dictionay.items():
         if val == value:
             return key

def get_vertices(List):
    if type(List)==list:
        res = sorted(range(len(List)), key = lambda sub: List[sub])
        return res
    if type(List)==dict:
        res = dict(sorted(List.items(), key = itemgetter(1), reverse = True)) 
        return res





#for clustering coefficent centrality values and vertices
# vertices_clustcd=get_vertices(CC)
# vertices_clustc=[]
# values_clustc=[]
# for i in vertices_clustcd:
#     vertices_clustc.append(i)
#     values_clustc.append(vertices_clustcd[i])
# #vertices_cc.reverse()
# #values_cc.reverse()
# print("vertices of clustc ", vertices_clustc)
# print("value of clustc: ", values_clustc)





#for mc centrality values and vertices

vertices_mc=get_vertices(mc)
vertices_m=[]
values_m=[]
for i in vertices_mc:
    vertices_m.append(i)
    values_m.append(vertices_mc[i])
#vertices_cc.reverse()
#values_cc.reverse()
print(f"vertices of mc when beta= {beta} :", vertices_m)
print("value of mc: ", values_m)

print("Top-10 Vertices: ",vertices_m[:10])
print("Top-10 Values: ",values_m[:10])


# n=10
# x=[]
# MC_=[]
# #print(len(G.nodes))
# for i in range(0,round(len(G.nodes())*0.75),n):
#     new_G=nx.Graph()
#     new_G = G.copy()
#     new_G.remove_nodes_from(vertices_m[:i])
#     #print(G.nodes)
#     #print("Gnodes",len(G.nodes))
#     #print("newGnodes",len(new_G.nodes))
#     x.append(i)
#     MC_.append(nx.number_connected_components(new_G))
#     #print(i)
# #print(x)
# #print(ISC_D)
# #print(len(nodes[:i]))

# df=pd.DataFrame(list(zip(x,MC_)),columns=['No_of_Nodes_Removed','No_of_Connected_Components'])
# print(df)
# df.to_excel('Bio_MC_No_Connected_Components.xlsx','Sheet1')

# df1=pd.DataFrame(list(zip(values_m,vertices_m)),columns=['Values','Vertices'])
# print(df1)
# df1.to_excel('Bio_MC_VN.xlsx','Sheet1')
# Out:
# vertices of mc when beta= 0.6 : [4420, 4653, 6006, 785, 5691, 1234, 4729, 4379, 1596, 6084, 4715, 3948, 6960, 883, 5400, 5185, 5653, 6791, 5225, 1133, 4936, 5405, 6047, 2069, 1707, 1317, 2767, 6348, 4807, 662, 3648, 6121, 1173, 1671, 658, 4647, 2629, 3975, 1566, 458, 505, 411, 5923, 6731, 4084, 558, 3166, 4623, 416, 4581, 5963, 845, 3221, 4815, 4281, 1832, 2039, 3241, 2924, 2489, 5724, 5022, 4258, 2877, 954, 2189, 4667, 3310, 214, 3969, 6409, 2588, 4413, 6600, 1416, 3442, 190, 1367, 6194, 6431, 5048, 2633, 2566, 271, 1845, 1356, 2299, 1833, 1812, 4683, 1233, 6120, 4225, 4856, 2214, 1984, 100, 886, 2525, 4386, 3635, 2338, 1855, 4337, 6706, 4732, 1652, 1708, 2584, 3419, 3844, 3173, 5314, 5748, 6871, 4002, 5643, 3932, 4238, 3762, 6181, 2259, 1195, 4902, 4670, 3062, 6015, 938, 5294, 1863, 2347, 376, 3040, 47, 4317, 189, 173, 3811, 1010, 2152, 2730, 2595, 1578, 5521, 2649, 2571, 5874, 435, 784, 2123, 2543, 2071, 1665, 707, 5580, 1182, 2703, 862, 80, 884, 2429, 4845, 5870, 1034, 1853, 3913, 4669, 361, 1301, 5738, 3805, 1377, 6423, 4852, 850, 5168, 5993, 4016, 6315, 5246, 1603, 2261, 5515, 2106, 1159, 5871, 149, 4691, 2362, 2854, 4945, 5896, 2094, 4458, 971, 6305, 3777, 6005, 1152, 2230, 449, 2450, 2496, 228, 5597, 3194, 5518, 3045, 267, 2621, 374, 3836, 1743, 4770, 1098, 319, 3492, 1455, 4415, 175, 116, 3657, 27, 2012, 6538, 2109, 290, 2559, 1436, 529, 166, 2249, 3729, 1811, 1929, 665, 526, 5540, 1402, 203, 4613, 873, 5801, 5603, 1824, 1775, 1595, 326, 603, 2773, 1727, 226, 3784, 1754, 4521, 345, 1864, 642, 2586, 6553, 178, 1380, 2600, 2709, 5172, 1569, 1646, 725, 566, 2859, 4919, 1422, 2509, 5649, 3851, 43, 3137, 3133, 4868, 714, 1770, 946, 694, 4448, 4640, 344, 6390, 270, 962, 5564, 4176, 3800, 6083, 4080, 1014, 875, 1971, 826, 2061, 506, 731, 3662, 3481, 895, 2603, 2158, 115, 1124, 5148, 905, 5250, 1112, 4764, 2225, 2090, 3487, 2070, 4847, 5377, 386, 627, 3678, 1192, 1771, 2599, 5485, 391, 3709, 41, 5550, 174, 4972, 14, 4040, 2804, 1025, 653, 1559, 2277, 2125, 412, 1868, 3956, 298, 1022, 132, 6108, 229, 2977, 2352, 162, 5534, 5615, 1956, 138, 455, 69, 4170, 997, 2135, 3229, 2905, 5559, 1155, 96, 1338, 3095, 1284, 743, 3367, 1426, 343, 5783, 20, 77, 5284, 131, 493, 1033, 1912, 817, 2153, 2312, 112, 5880, 383, 1043, 2313, 275, 622, 4678, 1170, 669, 6018, 3311, 1880, 838, 1281, 1300, 4063, 1428, 349, 42, 1337, 1660, 3531, 869, 2626, 1919, 2771, 3927, 5838, 4388, 2965, 904, 3327, 2358, 292, 164, 4594, 623, 1528, 1148, 260, 3287, 88, 2252, 1019, 5670, 194, 253, 1568, 3416, 322, 2850, 1502, 2942, 592, 336, 489, 759, 5673, 1363, 5886, 1286, 3462, 1623, 689, 25, 5598, 2704, 1726, 3002, 666, 2493, 2047, 369, 1573, 2628, 2194, 208, 441, 1957, 2843, 2145, 4338, 3153, 980, 185, 811, 4648, 747, 742, 413, 10, 1197, 663, 255, 450, 965, 844, 2136, 1230, 944, 1105, 541, 1370, 5, 951, 1736, 6094, 1413, 1064, 111, 3903, 1213, 373, 1679, 2785, 1058, 1918, 5695, 956, 2936, 5794, 2343, 528, 2770, 1462, 2653, 477, 407, 1561, 12, 551, 1752, 1078, 365, 573, 3864, 585, 4006, 1697, 2745, 4196, 1639, 808, 2758, 4, 1637, 1143, 381, 3378, 2962, 3043, 2124, 3249, 5818, 5793, 4824, 4034, 2925, 5703, 2449, 125, 197, 1677, 272, 882, 934, 552, 1755, 310, 1293, 649, 3309, 3455, 130, 4642, 1539, 6032, 942, 213, 1321, 967, 1959, 1309, 999, 1066, 1183, 65, 394, 2431, 1130, 3625, 920, 943, 2893, 991, 4723, 1139, 3798, 771, 5232, 2021, 1207, 3155, 1410, 3466, 274, 2545, 5676, 417, 4515, 2908, 1353, 2568, 1670, 1100, 1271, 2116, 655, 285, 840, 3898, 1848, 621, 2889, 2469, 829, 2953, 4089, 1191, 1349, 1012, 1907, 1051, 315, 726, 3036, 1341, 3732, 2029, 4578, 1361, 3484, 2321, 786, 1575, 206, 2697, 2246, 28, 471, 772, 3066, 1364, 207, 1901, 2900, 1883, 201, 1685, 17, 2033, 1715, 2182, 3067, 536, 5616, 1810, 170, 3404, 3749, 1479, 2558, 1120, 1821, 1095, 1783, 2023, 398, 2522, 2610, 3023, 5648, 5445, 5159, 1906, 6164, 1632, 717, 5536, 2203, 586, 1269, 1807, 1079, 153, 2250, 6336, 308, 1640, 427, 1516, 2440, 2932, 6235, 1962, 236, 1065, 339, 2042, 3989, 1215, 1887, 78, 768,  ...
# value of mc:  [17.449262799990738, 17.449262799990738, 17.449262799990738, 16.048477467438058, 15.94800290275217, 15.945527229724933, 15.320922284899515, 15.199587857579745, 15.090030459466398, 14.9845888316195, 14.939132119449207, 14.899421877102975, 14.831620100103562, 14.761594324045753, 14.358712747391543, 14.33862908768048, 14.283871305433806, 14.092292232250205, 13.904791524660771, 13.803529946515825, 13.803529946515825, 13.56145364233316, 12.523882688321132, 11.968207426228009, 11.21526096591183, 10.814476331791571, 10.472101179311139, 9.927995039545793, 9.342445308231582, 9.296745419128747, 9.145144089145084, 7.568198678566243, 7.09314402706839, 5.987954205650033, 5.908652487713806, 5.6734469051584995, 5.607165388720081, 5.5550686410266525, 5.521572420598563, 5.5204883435461785, 5.432669019371757, 5.398015650490913, 5.386050784957667, 5.386050784957667, 5.372638087631262, 5.369226427009218, 5.3654795816961425, 5.353506971967348, 5.346447416171924, 5.340540868100788, 5.243459124725424, 5.210459838666384, 5.170220415808885, 5.150273312618509, 5.127900605024445, 5.096858616840844, 5.094701467026581, 5.086903173354016, 5.028244582229996, 4.9924162605347595, 4.988061305925835, 4.983024946984017, 4.967229488704537, 4.955021783611194, 4.937391691000098, 4.928316536716746, 4.925440565349798, 4.897769937379156, 4.854411825622118, 4.818901290194248, 4.796209510153625, 4.782122432721337, 4.754770885188799, 4.715556096534754, 4.577279702493448, 4.573837441877761, 4.397887344901391, 4.346169182962948, 4.173131801800667, 4.009879012721335, 4.0050684983170255, 3.9976943973133974, 3.978881952034601, 3.660251391499719, 3.5445201481798976, 3.342148393400233, 3.319464087073765, 3.29616868193831, 3.2464286921207868, 3.2371559197774795, 3.2367756064976225, 3.2025610133670552, 3.18755061453974, 3.1029903640824172, 3.0745777378834314, 3.069256661367376, 3.05701430774916, 3.05701430774916, 3.0431954133637698, 3.0367622201702873, 3.0227643405357125, 3.0194466572908656, 2.9601527502880525, 2.9018678593695575, 2.802719260274659, 2.7619917511942864, 2.756792995749032, 2.7395479727636567, 2.712189128320756, 2.6870358700466617, 2.6857839704014417, 2.675444480951707, 2.6726623015742024, 2.646347156251915, 2.646347156251915, 2.6404230722279536, 2.5728961865375632, 2.5449331938138706, 2.5301045633000654, 2.5286036125089058, 2.526307193231951, 2.5248587587896822, 2.5210778582437143, 2.5146575968527234, 2.5110450224263823, 2.5074586931764067, 2.497643054937277, 2.489811219311948, 2.4874519875064056, 2.4485318083277625, 2.388651784722074, 2.368215407959053, 2.363764609392649, 2.3556976506297396, 2.353631392122597, 2.3512600521620173, 2.317904750409291, 2.3108205961124795, 2.2178470668215717, 2.207658141039017, 2.1892304182694655, 2.1487784268092716, 2.138495540090879, 2.1025548088125823, 2.098347454260343, 2.0974470523045405, 2.0915644791787447, 2.048107294250974, 2.0335349830007274, 2.007239062109291, 1.992793683167507, 1.983172467752924, 1.9714877025596882, 1.9487297997274138, 1.930092599290163, 1.927972695588466, 1.9198551260628036, 1.916384800978806, 1.9132437481026814, 1.8397625076597028, 1.810921103710616, 1.7762687704783913, 1.7762687704783913, 1.7681642724486086, 1.7424263380260578, 1.7410527550800177, 1.7225877645117338, 1.7175508077068278, 1.709980719397946, 1.7015034619138956, 1.698682195808275, 1.6833026365701456, 1.6639436653602315, 1.6625754607123673, 1.6546052440626775, 1.6535750050898161, 1.6403049261510212, 1.6232623087913445, 1.6194102326576945, 1.6143016143790174, 1.6082990940624655, 1.607564358157825, 1.6062860574986653, 1.6024920521324677, 1.6011976198832552, 1.594691859770175, 1.593819252668245, 1.588474080986021, 1.588051364103832, 1.5829680766701808, 1.5715416972807725, 1.5704081914707964, 1.5697555247656239, 1.5676082905773465, 1.5668192695091583, 1.5622990681696818, 1.5538870474950692, 1.5479853712752591, 1.5475380454300522, 1.5475380454300522, 1.5408969799051384, 1.5408969799051384, 1.537121180755523, 1.5370845585435748, 1.5334 ...
# Top-10 Vertices:  [4420, 4653, 6006, 785, 5691, 1234, 4729, 4379, 1596, 6084]
# Top-10 Values:  [17.449262799990738, 17.449262799990738, 17.449262799990738, 16.048477467438058, 15.94800290275217, 15.945527229724933, 15.320922284899515, 15.199587857579745, 15.090030459466398, 14.9845888316195]
