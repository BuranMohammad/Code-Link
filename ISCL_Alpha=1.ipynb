# %%
import csv
import math 
import networkx as nx
import numpy as np
from operator import itemgetter
from numpy import linalg as LA
import pandas as pd
G=nx.Graph()
f = open("bio-dmela.txt", "r")
edge1=[]
edge2=[]
nodelist=[]
for x in f:
  e1,e2=x.split()
  edge1.append(int(e1)-1)
  edge2.append(int(e2)-1)
  for i in (int(e1)-1,int(e2)-1):
      if i not in nodelist:
          nodelist.append(i)
n=len(nodelist)

for  i in range(0, len(edge1)):
    G.add_edge(edge1[i], edge2[i])
D={node:val for (node, val) in G.degree()}
CC=nx.clustering(G)
d=[val for (node,val) in G.degree()]
S_del=min(d)



def isc(node):
    ISC_value=0
    x=list(G.neighbors(node))
#     print(f"Neighbors of node {node} are:",x)
#     print(f"length of {x} is:{len(x)}")
    N=0;
    for i in range(0,len(x)):
        if G.degree(x[i])==S_del:
#             print(x[i])
            N=N+1
#     print(f'The Number of Neighbors for node {node} with deg delta is:', {N})
    ISC_value=N*G.degree(node)
    return ISC_value




#beta=[0,0.2,0.4,0.6,0.8,1]
beta=1.0
def MCisc(v, alpha):
    sum=0
    for u in nodelist:
        if v!=u:
            d_ij=nx.shortest_path_length(G, source=u, target=v)
            sum=sum+(CC[u]+isc(u)/n)/d_ij
    return sum*(beta*CC[v]+(1-beta)*isc(v)/n)
                     



mc={}
alpha=0.0
for v in nodelist:
    #print(MCisc(v,alpha))
    mc[v]=MCisc(v,alpha)


def get_key(dictionay, val):
    for key, value in dictionay.items():
         if val == value:
             return key

def get_vertices(List):
    if type(List)==list:
        res = sorted(range(len(List)), key = lambda sub: List[sub])
        return res
    if type(List)==dict:
        res = dict(sorted(List.items(), key = itemgetter(1), reverse = True)) 
        return res





#for clustering coefficent centrality values and vertices
# vertices_clustcd=get_vertices(CC)
# vertices_clustc=[]
# values_clustc=[]
# for i in vertices_clustcd:
#     vertices_clustc.append(i)
#     values_clustc.append(vertices_clustcd[i])
# #vertices_cc.reverse()
# #values_cc.reverse()
# print("vertices of clustc ", vertices_clustc)
# print("value of clustc: ", values_clustc)





#for mc centrality values and vertices

vertices_mc=get_vertices(mc)
vertices_m=[]
values_m=[]
for i in vertices_mc:
    vertices_m.append(i)
    values_m.append(vertices_mc[i])
#vertices_cc.reverse()
#values_cc.reverse()
print(f"vertices of mc when beta= {beta} :", vertices_m)
print("value of mc: ", values_m)

print("Top-10 Vertices: ",vertices_m[:10])
print("Top-10 Values: ",values_m[:10])


# n=10
# x=[]
# MC_=[]
# #print(len(G.nodes))
# for i in range(0,round(len(G.nodes())*0.75),n):
#     new_G=nx.Graph()
#     new_G = G.copy()
#     new_G.remove_nodes_from(vertices_m[:i])
#     #print(G.nodes)
#     #print("Gnodes",len(G.nodes))
#     #print("newGnodes",len(new_G.nodes))
#     x.append(i)
#     MC_.append(nx.number_connected_components(new_G))
#     #print(i)
# #print(x)
# #print(ISC_D)
# #print(len(nodes[:i]))

# df=pd.DataFrame(list(zip(x,MC_)),columns=['No_of_Nodes_Removed','No_of_Connected_Components'])
# print(df)
# df.to_excel('Bio_MC_No_Connected_Components.xlsx','Sheet1')

# df1=pd.DataFrame(list(zip(values_m,vertices_m)),columns=['Values','Vertices'])
# print(df1)
# df1.to_excel('Bio_MC_VN.xlsx','Sheet1')
# Out:
# vertices of mc when beta= 1.0 : [4420, 4653, 6006, 785, 5691, 1234, 4729, 4379, 1596, 6084, 4715, 3948, 6960, 883, 5400, 5185, 5653, 6791, 5225, 1133, 4936, 5405, 6047, 2069, 1707, 1317, 2767, 6348, 4807, 3648, 6121, 1173, 1671, 658, 4647, 2629, 3975, 1566, 458, 505, 411, 5923, 6731, 4084, 558, 3166, 4623, 416, 4581, 5963, 845, 3221, 4815, 4281, 1832, 2039, 3241, 2924, 2489, 5724, 5022, 4258, 2877, 954, 2189, 4667, 3310, 3969, 6409, 2588, 4413, 6600, 1416, 3442, 190, 1367, 6194, 6431, 5048, 2633, 2566, 271, 1845, 1356, 2299, 1833, 1812, 4683, 1233, 6120, 4225, 4856, 2214, 1984, 100, 886, 4386, 3635, 2525, 2338, 1855, 4337, 6706, 4732, 1652, 1708, 2584, 3419, 3844, 3173, 5314, 5748, 6871, 4002, 5643, 3932, 4238, 3762, 6181, 2259, 1195, 4902, 4670, 3062, 6015, 938, 5294, 1863, 2347, 376, 3040, 47, 4317, 189, 173, 3811, 2152, 1010, 2730, 2595, 1578, 5521, 2649, 2571, 5874, 435, 784, 2123, 2543, 2071, 1665, 5580, 1182, 2703, 80, 862, 884, 2429, 4845, 5870, 1034, 1853, 3913, 4669, 361, 1301, 5738, 3805, 6423, 4852, 850, 5168, 5993, 4016, 6315, 5246, 1603, 2261, 5515, 2106, 1159, 4691, 2362, 5871, 2854, 4945, 5896, 2094, 4458, 971, 6305, 3777, 6005, 1152, 2230, 449, 2450, 2496, 228, 5597, 3194, 5518, 3045, 2621, 374, 3836, 1743, 4770, 1098, 3492, 1455, 175, 149, 116, 3657, 4415, 27, 2012, 6538, 2109, 2559, 1436, 529, 166, 290, 2249, 3729, 1811, 1929, 526, 5540, 1402, 4613, 665, 873, 5801, 5603, 1824, 1775, 1595, 326, 2773, 1727, 226, 319, 1754, 4521, 1377, 3784, 345, 1864, 642, 6553, 178, 1380, 2600, 2709, 5172, 1569, 1646, 725, 2859, 4919, 1422, 5649, 566, 3851, 43, 3137, 714, 1770, 946, 4448, 4640, 344, 4868, 6390, 270, 2509, 962, 3800, 4080, 1014, 875, 5564, 1971, 4176, 826, 694, 2061, 731, 3662, 895, 2603, 2158, 3481, 115, 1124, 5148, 5250, 1112, 4764, 2225, 2090, 3487, 2070, 4847, 5377, 6083, 386, 627, 3678, 1771, 2599, 5485, 3709, 2586, 41, 4972, 1192, 4040, 2804, 1025, 653, 1559, 14, 2125, 1868, 3956, 1022, 132, 6108, 229, 2977, 2352, 162, 5534, 5615, 1956, 69, 4170, 391, 2135, 412, 3229, 2277, 2905, 5559, 96, 1338, 997, 506, 3095, 1284, 1155, 3367, 343, 5783, 20, 131, 493, 1033, 1912, 5284, 2153, 2312, 1426, 112, 5880, 1043, 77, 275, 622, 4678, 1170, 6018, 3311, 838, 1281, 1300, 4063, 1428, 349, 42, 2313, 1660, 3531, 2626, 1919, 2771, 3927, 5838, 669, 2965, 3327, 1337, 1880, 292, 164, 4594, 623, 817, 1528, 260, 4388, 3287, 904, 88, 2252, 5670, 194, 1568, 3416, 2850, 1502, 2942, 592, 759, 2358, 869, 5673, 1148, 5886, 1286, 3462, 1623, 336, 689, 1019, 5598, 2704, 1726, 666, 2493, 2047, 369, 1573, 2628, 322, 441, 2843, 2145, 4338, 980, 185, 811, 4648, 747, 742, 413, 10, 1197, 965, 1957, 2136, 1230, 1105, 255, 541, 1370, 1736, 6094, 1413, 3153, 1064, 3903, 1213, 373, 3002, 2785, 1918, 5794, 2343, 528, 2653, 407, 3133, 1078, 573, 585, 4006, 1697, 2745, 4196, 808, 2758, 4, 1143, 381, 3378, 2962, 1058, 2124, 1561, 3249, 5793, 4824, 4034, 2925, 5703, 3043, 1677, 272, 882, 934, 552, 1755, 310, 1639, 5818, 477, 3309, 3455, 1462, 130, 4642, 6032, 942, 1959, 1309, 111, 1183, 3864, 1130, 3625, 920, 943, 2893, 999, 5695, 1321, 3798, 771, 5232, 3155, 274, 2545, 5676, 417, 4515, 2908, 1353, 1271, 944, 4723, 2936, 621, 2889, 2431, 1139, 1539, 829, 3466, 2953, 365, 2568, 1191, 1349, 1848, 1012, 2449, 1907, 1051, 394, 315, 726, 3036, 2029, 4578, 991, 3484, 786, 655, 1575, 206, 471, 4089, 649, 1364, 1901, 2900, 1883, 1361, 201, 17, 2033, 3898, 3067, 536, 3404, 3749, 1479, 3732, 2558, 1821, 1095, 1783, 2023, 967, 2246, 398, 2522, 5616, 3023, 5445, 5159, 6164, 1632, 5536, 2203, 1269, 2250, 6336, 308, 1640, 170, 2932, 6235, 2042, 3989, 772, 1215, 5648, 3206, 1061, 663, 2021, 1906, 2452, 1280, 2440, 905, 2165, 427, 1363, 743, 4491, 1146, 975, 259, 2770, 1341, 1120, 3066, 660, 2697, 1359, 844, 446, 406, 1715, 1788, 2037, 5556, 1598, 452, 2427, 1887, 209, 790, 551, 1810, 1774, 1323, 320, 1153, 1807, 2672, 918, 5134, 1307, 601, 1226, 1924, 78, 970, 5532, 125, 1079, 1962, 5861, 1000, 2677, 4530, 2204, 22, 1633, 1232, 1947, 2735, 1867, 339, 986, 1499, 8 ...
# value of mc:  [29.08210466665123, 29.08210466665123, 29.08210466665123, 26.747462445730097, 26.580004837920285, 26.575878716208223, 25.534870474832527, 25.332646429299576, 25.15005076577733, 24.974314719365836, 24.898553532415345, 24.832369795171626, 24.719366833505937, 24.602657206742922, 23.93118791231924, 23.897715146134136, 23.80645217572301, 23.48715372041701, 23.174652541101285, 23.005883244193043, 23.005883244193043, 22.602422737221932, 20.873137813868553, 19.947012377046683, 18.692101609853047, 18.02412721965262, 17.453501965518566, 16.54665839924299, 15.57074218038597, 15.241906815241807, 12.613664464277072, 11.82190671178065, 9.979923676083388, 9.847754146189676, 9.455744841930834, 9.345275647866803, 9.25844773504442, 9.202620700997606, 9.200813905910298, 9.054448365619596, 8.996692750818188, 8.976751308262777, 8.976751308262777, 8.95439681271877, 8.948710711682029, 8.935214341460464, 8.922511619945581, 8.910745693619873, 8.900901446834649, 8.732011827971135, 8.684099731110638, 8.617034026348142, 8.583788854364181, 8.546501008374076, 8.494764361401407, 8.491169111710967, 8.478171955590026, 8.380407637049993, 8.320693767557932, 8.313435509876392, 8.305041578306694, 8.278715814507562, 8.25836963935199, 8.228986151666831, 8.213860894527912, 8.20906760891633, 8.162949895631925, 8.031502150323746, 7.993682516922709, 7.9413208819633825, 7.924618141981332, 7.859260160891257, 7.628799504155746, 7.623062403129603, 7.329812241502318, 7.243615304938246, 6.955219669667779, 6.683131687868892, 6.675114163861709, 6.655621915808212, 6.631469920057668, 6.1004189858328655, 5.90753358029983, 5.570247322333722, 5.532440145122942, 5.493614469897184, 5.410714486867978, 5.3952598662958, 5.394626010829372, 5.337601688945092, 5.312584357566234, 5.171650606804029, 5.124296229805719, 5.115427768945628, 5.0950238462486, 5.0950238462486, 5.061270366950479, 5.037940567559521, 5.034360184394439, 5.032411095484776, 4.933587917146755, 4.836446432282596, 4.671198767124432, 4.603319585323811, 4.5946549929150535, 4.565913287939428, 4.520315213867927, 4.478393116744437, 4.476306617335736, 4.459074134919511, 4.454437169290337, 4.410578593753192, 4.410578593753192, 4.400705120379922, 4.288160310895939, 4.2415553230231176, 4.2168409388334425, 4.214339354181511, 4.210511988719919, 4.2080979313161375, 4.2017964304061906, 4.191095994754539, 4.185075037377304, 4.179097821960678, 4.162738424895462, 4.149685365519914, 4.145753312510676, 4.080886347212938, 3.9810863078701235, 3.9470256799317553, 3.939607682321082, 3.9261627510495662, 3.9227189868709953, 3.9187667536033626, 3.8631745840154847, 3.851367660187466, 3.6794302350650283, 3.677839344356889, 3.6487173637824424, 3.581297378015453, 3.5641592334847982, 3.504258014687637, 3.4972457571005715, 3.4957450871742344, 3.485940798631241, 3.4135121570849574, 3.389224971667879, 3.3453984368488188, 3.321322805279179, 3.305287446254874, 3.28581283759948, 3.2168209988169387, 3.213287825980777, 3.199758543438006, 3.1887395801711356, 3.13157846599852, 3.066270846099505, 3.0182018395176935, 2.9604479507973194, 2.9604479507973194, 2.913638351992102, 2.904043896710096, 2.90175459180003, 2.8709796075195566, 2.862584679511379, 2.8499678656632432, 2.835839103189826, 2.831136993013792, 2.773239442267053, 2.770959101187279, 2.7576754067711295, 2.7559583418163607, 2.7338415435850356, 2.7054371813189078, 2.699017054429491, 2.6905026906316962, 2.68049849010411, 2.679273930263042, 2.6771434291644427, 2.6708200868874465, 2.6686626998054255, 2.6474568016433686, 2.646752273506387, 2.640320012380387, 2.6382801277836347, 2.619236162134621, 2.617346985784661, 2.6162592079427065, 2.612680484295578, 2.6113654491819305, 2.6038317802828033, 2.5898117458251155, 2.579975618792099, 2.5792300757167537, 2.5792300757167537, 2.568161633175231, 2.568161633175231, 2.5618686345925386, 2.5618075975726247, 2.5557955536139647, 2.550394915559856, 2.548551102383718, 2.5439181457301454, 2.499665129561328, 2.49507430591219, 2.4920241764491786, 2.480967939187208, ...
# Top-10 Vertices:  [4420, 4653, 6006, 785, 5691, 1234, 4729, 4379, 1596, 6084]
# Top-10 Values:  [29.08210466665123, 29.08210466665123, 29.08210466665123, 26.747462445730097, 26.580004837920285, 26.575878716208223, 25.534870474832527, 25.332646429299576, 25.15005076577733, 24.974314719365836]
