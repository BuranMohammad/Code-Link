# %%
import csv
import math 
import networkx as nx
import numpy as np
from operator import itemgetter
from numpy import linalg as LA
import pandas as pd
G=nx.Graph()
f = open("bio-dmela.txt", "r")
edge1=[]
edge2=[]
nodelist=[]
for x in f:
  e1,e2=x.split()
  edge1.append(int(e1)-1)
  edge2.append(int(e2)-1)
  for i in (int(e1)-1,int(e2)-1):
      if i not in nodelist:
          nodelist.append(i)
n=len(nodelist)

for  i in range(0, len(edge1)):
    G.add_edge(edge1[i], edge2[i])
D={node:val for (node, val) in G.degree()}
CC=nx.clustering(G)
d=[val for (node,val) in G.degree()]
S_del=min(d)



def isc(node):
    ISC_value=0
    x=list(G.neighbors(node))
#     print(f"Neighbors of node {node} are:",x)
#     print(f"length of {x} is:{len(x)}")
    N=0;
    for i in range(0,len(x)):
        if G.degree(x[i])==S_del:
#             print(x[i])
            N=N+1
#     print(f'The Number of Neighbors for node {node} with deg delta is:', {N})
    ISC_value=N*G.degree(node)
    return ISC_value




#beta=[0,0.2,0.4,0.6,0.8,1]
beta=0.8
def MCisc(v, alpha):
    sum=0
    for u in nodelist:
        if v!=u:
            d_ij=nx.shortest_path_length(G, source=u, target=v)
            sum=sum+(CC[u]+isc(u)/n)/d_ij
    return sum*(beta*CC[v]+(1-beta)*isc(v)/n)
                     



mc={}
alpha=0.0
for v in nodelist:
    #print(MCisc(v,alpha))
    mc[v]=MCisc(v,alpha)


def get_key(dictionay, val):
    for key, value in dictionay.items():
         if val == value:
             return key

def get_vertices(List):
    if type(List)==list:
        res = sorted(range(len(List)), key = lambda sub: List[sub])
        return res
    if type(List)==dict:
        res = dict(sorted(List.items(), key = itemgetter(1), reverse = True)) 
        return res





#for clustering coefficent centrality values and vertices
# vertices_clustcd=get_vertices(CC)
# vertices_clustc=[]
# values_clustc=[]
# for i in vertices_clustcd:
#     vertices_clustc.append(i)
#     values_clustc.append(vertices_clustcd[i])
# #vertices_cc.reverse()
# #values_cc.reverse()
# print("vertices of clustc ", vertices_clustc)
# print("value of clustc: ", values_clustc)





#for mc centrality values and vertices

vertices_mc=get_vertices(mc)
vertices_m=[]
values_m=[]
for i in vertices_mc:
    vertices_m.append(i)
    values_m.append(vertices_mc[i])
#vertices_cc.reverse()
#values_cc.reverse()
print(f"vertices of mc when beta= {beta} :", vertices_m)
print("value of mc: ", values_m)

print("Top-10 Vertices: ",vertices_m[:10])
print("Top-10 Values: ",values_m[:10])


# n=10
# x=[]
# MC_=[]
# #print(len(G.nodes))
# for i in range(0,round(len(G.nodes())*0.75),n):
#     new_G=nx.Graph()
#     new_G = G.copy()
#     new_G.remove_nodes_from(vertices_m[:i])
#     #print(G.nodes)
#     #print("Gnodes",len(G.nodes))
#     #print("newGnodes",len(new_G.nodes))
#     x.append(i)
#     MC_.append(nx.number_connected_components(new_G))
#     #print(i)
# #print(x)
# #print(ISC_D)
# #print(len(nodes[:i]))

# df=pd.DataFrame(list(zip(x,MC_)),columns=['No_of_Nodes_Removed','No_of_Connected_Components'])
# print(df)
# df.to_excel('Bio_MC_No_Connected_Components.xlsx','Sheet1')

# df1=pd.DataFrame(list(zip(values_m,vertices_m)),columns=['Values','Vertices'])
# print(df1)
# df1.to_excel('Bio_MC_VN.xlsx','Sheet1')
# Out:
# vertices of mc when beta= 0.8 : [4420, 4653, 6006, 785, 5691, 1234, 4729, 4379, 1596, 6084, 4715, 3948, 6960, 883, 5400, 5185, 5653, 6791, 5225, 1133, 4936, 5405, 6047, 2069, 1707, 1317, 2767, 6348, 4807, 3648, 6121, 1173, 1671, 658, 4647, 2629, 3975, 1566, 458, 505, 411, 5923, 6731, 4084, 558, 3166, 4623, 416, 4581, 5963, 845, 3221, 4815, 4281, 1832, 2039, 3241, 2924, 2489, 5724, 5022, 4258, 2877, 954, 2189, 4667, 3310, 3969, 6409, 2588, 4413, 6600, 1416, 3442, 190, 1367, 6194, 6431, 5048, 2633, 2566, 271, 1845, 662, 1356, 2299, 1833, 1812, 4683, 1233, 6120, 4225, 4856, 2214, 1984, 100, 886, 4386, 2525, 3635, 2338, 1855, 4337, 6706, 4732, 1652, 1708, 2584, 3419, 3844, 3173, 5314, 5748, 6871, 4002, 5643, 3932, 4238, 3762, 6181, 2259, 1195, 4902, 4670, 3062, 6015, 938, 5294, 1863, 2347, 376, 3040, 47, 4317, 189, 173, 3811, 1010, 2152, 2730, 2595, 1578, 5521, 2649, 2571, 5874, 435, 784, 2123, 2543, 2071, 1665, 5580, 1182, 2703, 80, 214, 862, 884, 2429, 4845, 5870, 1034, 1853, 3913, 4669, 361, 1301, 5738, 3805, 6423, 4852, 850, 5168, 5993, 4016, 6315, 5246, 1603, 2261, 5515, 2106, 1159, 4691, 5871, 2362, 2854, 4945, 5896, 2094, 4458, 971, 6305, 3777, 6005, 1152, 2230, 449, 2450, 2496, 228, 5597, 3194, 5518, 3045, 2621, 374, 149, 3836, 1743, 4770, 1098, 3492, 1455, 175, 4415, 116, 3657, 27, 2012, 6538, 2109, 1377, 2559, 1436, 529, 290, 166, 2249, 3729, 319, 1811, 1929, 526, 5540, 665, 1402, 4613, 873, 5801, 5603, 1824, 1775, 1595, 326, 2773, 1727, 226, 1754, 4521, 3784, 345, 1864, 642, 6553, 178, 1380, 2600, 2709, 5172, 1569, 1646, 725, 2859, 566, 4919, 1422, 5649, 3851, 43, 3137, 2509, 714, 1770, 946, 4448, 4640, 4868, 344, 6390, 270, 962, 694, 3800, 5564, 4176, 4080, 1014, 875, 1971, 826, 2061, 731, 3662, 895, 3481, 2603, 2158, 2586, 115, 1124, 5148, 6083, 5250, 1112, 4764, 2225, 2090, 3487, 2070, 4847, 5377, 386, 627, 3678, 1771, 2599, 5485, 3709, 1192, 41, 4972, 4040, 2804, 506, 14, 1025, 653, 1559, 2125, 391, 1868, 3956, 1022, 132, 6108, 229, 2977, 2352, 162, 5534, 5615, 1956, 412, 69, 2277, 4170, 2135, 3229, 2905, 997, 5559, 96, 1338, 1155, 3095, 1284, 3367, 343, 5783, 20, 131, 493, 5284, 1033, 1912, 1426, 77, 2153, 2312, 112, 5880, 1043, 275, 622, 4678, 1170, 3133, 6018, 817, 2313, 3311, 838, 1281, 1300, 4063, 1428, 349, 42, 669, 1660, 3531, 2626, 1919, 1880, 2771, 3927, 5838, 1337, 2965, 3327, 707, 292, 164, 4594, 4388, 623, 1528, 904, 260, 3287, 88, 2252, 5670, 194, 869, 1568, 3416, 2358, 2850, 1148, 1502, 2942, 592, 759, 5673, 1019, 5886, 336, 1286, 3462, 1623, 689, 5598, 2704, 1726, 666, 322, 2493, 2047, 369, 1573, 2628, 441, 2843, 2145, 4338, 980, 185, 811, 4648, 747, 742, 413, 10, 1197, 1957, 965, 3002, 255, 3153, 2136, 1230, 1105, 541, 1370, 1736, 6094, 1413, 1064, 3903, 1213, 373, 2785, 905, 1918, 5794, 2343, 528, 2653, 407, 1078, 573, 585, 4006, 1058, 1697, 2745, 4196, 808, 2758, 1561, 4, 1143, 381, 3378, 2962, 111, 477, 2124, 3249, 1462, 1639, 5793, 4824, 4034, 3043, 2925, 5703, 5818, 1677, 272, 882, 5695, 934, 552, 1755, 310, 743, 944, 3864, 3309, 3455, 130, 4642, 6032, 942, 267, 1959, 2936, 1309, 1183, 1321, 203, 999, 1130, 3625, 920, 943, 365, 2893, 603, 3798, 771, 5232, 1539, 3155, 1363, 2449, 2431, 274, 2545, 5676, 417, 4723, 4515, 1139, 2908, 1353, 1271, 663, 394, 174, 649, 3466, 621, 2889, 2568, 991, 829, 2953, 1848, 1191, 1349, 1012, 1907, 1051, 655, 844, 315, 726, 967, 138, 4089, 3036, 2029, 4578, 3484, 786, 2770, 1575, 3898, 206, 471, 1361, 1364, 1901, 2900, 1883, 201, 3732, 551, 17, 2033, 2246, 3067, 536, 2021, 3404, 3749, 1479, 2558, 1821, 1095, 5616, 1783, 2023, 253, 398, 2522, 125, 3023, 772, 5, 5445, 5159, 170, 6164, 1632, 5536, 2203, 1269, 2250, 6336, 308, 1640, 2932, 5648, 1341, 6235, 213, 12, 2042, 3989, 1215, 208, 2697, 3066, 1906, 3206, 1120, 455, 2440, 1061, 1715, 427, 1670, 2452, 1280, 1810, 2165, 298, 4491, 1146, 5550, 975, 259, 489, 1807, 1887, 1207, 1079, 660, 1359, 2469, 2427, 1962, 446, 406, 452, 78, 5532, 339, 586, 1788, 2037, 5556, 1598, 2204, 4530, 209, 790, 970, 1307, 1774, 1323, 320 ...
# value of mc:  [23.265683733320984, 23.265683733320984, 23.265683733320984, 21.397969956584078, 21.26400387033623, 21.26070297296658, 20.427896379866024, 20.26611714343966, 20.120040612621864, 19.97945177549267, 19.918842825932277, 19.8658958361373, 19.77549346680475, 19.68212576539434, 19.14495032985539, 19.11817211690731, 19.045161740578408, 18.789722976333607, 18.539722032881027, 18.404706595354437, 18.404706595354437, 18.081938189777546, 16.698510251094845, 15.957609901637348, 14.95368128788244, 14.419301775722095, 13.962801572414854, 13.237326719394392, 12.456593744308776, 12.193525452193446, 10.090931571421658, 9.45752536942452, 7.983938940866711, 7.878203316951741, 7.564595873544667, 7.4762205182934425, 7.406758188035537, 7.362096560798085, 7.360651124728238, 7.243558692495676, 7.197354200654551, 7.1814010466102225, 7.1814010466102225, 7.163517450175017, 7.158968569345624, 7.150346961578303, 7.138009295956465, 7.128596554895899, 7.1207211574677185, 6.98773547634828, 6.9472797848885115, 6.893627221078514, 6.867031083491345, 6.8372008066992604, 6.795811489121125, 6.792935289368774, 6.782537564472022, 6.704326109639995, 6.656555014046346, 6.650748407901113, 6.6440332626453555, 6.62297265160605, 6.606695711481593, 6.5831889213334644, 6.571088715622329, 6.5672540871330645, 6.5303599165055415, 6.425201720258997, 6.394946013538167, 6.36172165734236, 6.339694513585066, 6.287408128713006, 6.103039603324597, 6.098449922503682, 5.863849793201855, 5.794892243950597, 5.564175735734223, 5.346505350295113, 5.340091331089368, 5.326658156560805, 5.305175936046135, 4.880335188666293, 4.726026864239865, 4.686978635840167, 4.456197857866977, 4.425952116098355, 4.394891575917748, 4.328571589494383, 4.3162078930366405, 4.315700808663498, 4.270081351156075, 4.250067486052987, 4.137320485443224, 4.099436983844575, 4.092342215156502, 4.07601907699888, 4.07601907699888, 4.049016293560383, 4.038777798879105, 4.030352454047618, 4.025928876387821, 3.946870333717404, 3.8691571458260765, 3.7369590136995456, 3.6826556682590486, 3.6757239943320434, 3.6527306303515426, 3.6162521710943416, 3.5827144933955495, 3.581045293868589, 3.5672593079356094, 3.56354973543227, 3.5284628750025537, 3.5284628750025537, 3.520564096303938, 3.430528248716751, 3.3932442584184943, 3.3734727510667537, 3.3714714833452084, 3.368409590975935, 3.36647834505291, 3.3614371443249524, 3.352876795803631, 3.3480600299018435, 3.3432782575685427, 3.3301907399163695, 3.319748292415931, 3.3166026500085413, 3.26470907777035, 3.184869046296099, 3.1576205439454044, 3.1516861458568655, 3.140930200839653, 3.1381751894967964, 3.1350134028826906, 3.090539667212388, 3.081094128149973, 2.9478432055892307, 2.943544188052023, 2.918973891025954, 2.8650379024123622, 2.851327386787839, 2.80340641175011, 2.7977966056804573, 2.7965960697393877, 2.788752638904993, 2.730809725667966, 2.7113799773343032, 2.676318749479055, 2.657058244223343, 2.644229957003899, 2.6286502700795844, 2.573456799053551, 2.5706302607846214, 2.559806834750405, 2.550991664136909, 2.5297400972663793, 2.523981633488663, 2.4530166768796042, 2.414561471614155, 2.3683583606378558, 2.3683583606378558, 2.340901312220355, 2.3232351173680774, 2.321403673440024, 2.296783686015645, 2.2900677436091033, 2.2799742925305946, 2.2686712825518605, 2.264909594411034, 2.2185915538136425, 2.2167672809498233, 2.2061403254169036, 2.2047666734530886, 2.187073234868029, 2.1643497450551266, 2.159213643543593, 2.152402152505357, 2.144398792083288, 2.1434191442104336, 2.1417147433315544, 2.1366560695099577, 2.1349301598443406, 2.117965441314695, 2.1175059360752813, 2.11740181880511, 2.110624102226908, 2.095388929707697, 2.093877588627729, 2.0930073663541657, 2.0901443874364625, 2.089092359345545, 2.0830654242262425, 2.0718493966600926, 2.0639804950336793, 2.063384060573403, 2.063384060573403, 2.054529306540185, 2.054529306540185, 2.049494907674031, 2.0494460780580996, 2.044636442891172, 2.0403159324478852, 2.038840881906975, 2.0351345165841166, 1.9997321036490 ...
# Top-10 Vertices:  [4420, 4653, 6006, 785, 5691, 1234, 4729, 4379, 1596, 6084]
# Top-10 Values:  [23.265683733320984, 23.265683733320984, 23.265683733320984, 21.397969956584078, 21.26400387033623, 21.26070297296658, 20.427896379866024, 20.26611714343966, 20.120040612621864, 19.97945177549267]
